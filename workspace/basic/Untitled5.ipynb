# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
#데이커 시각화

data=[20,30,40]
x=[1,2,3]
plt.plot(x.data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-50e2d1b4992a> in <module>
#       3 data=[20,30,40]
#       4 x=[1,2,3]
# ----> 5 plt.plot(x.data)
#       6 plt.show()
#
# AttributeError: 'list' object has no attribute 'data'

# %%
from matplotlib import pyplot as plt
 
plt.plot([1,2,3], [110,130,120])
plt.show()

# %%
plt.plot(["Seoul","Paris","Seattle"], [30,25,55])
plt.xlabel('City')
plt.ylabel('Response')
plt.title('Experiment Result','g')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a9ae0655458f> in <module>
# ----> 1 plt.plot(["Seoul","Paris","Seattle"], [30,25,55])
#       2 plt.xlabel('City')
#       3 plt.ylabel('Response')
#       4 plt.title('Experiment Result','g')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
y = [4, 4, 8, 4 ,8,5,7,4,8,5,6,9,8,5,4,5,21,4,5,2,5,4,4,1,2,5,4,5,5]

x = range(len(y))
plt.bar(x, y, width=0.8, color="green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1,50)

y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.plot(x,y1,'r-*', 
         label=r'$sin(4 \pi x)$',lw=1)
plt.plot(x,y2,'b--o',
   label=r'$ e^{-2x} sin(4\pi x) $',lw=1)
plt.title(r'$sin(4 \pi x)$ vs. $ e^{-2x} sin(4\pi x)$')
plt.xlabel('x')
plt.ylabel('y')
plt.text(0.5,-1.0,r'This is sample')
plt.axis([0,1,-1.5,1.5])
plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
####색깔 바꾸기...........plt.plot(x,y,'내가 원하는컬러')
#####  x축 y축 라벨 붙이기 ...;........plt.xlabel(‘X축 라벨명'), plt.ylabel(‘Y축 라벨명')
x = np.arange(1,10)
y = x*5


plt.xlabel('die'),plt.ylabel('birth')
plt.plot(x,y,'^r')
plt.show()

# %%
x = np.arange(1,10,0.1)
y = x*0.2
y2 = np.sin(x)

plt.plot(x,y,'b',label='dath')
plt.plot(x,y2,'r',label='birth')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('dath and birth')
plt.legend(loc='upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline




xdat=list(range(30))
ydata=[]

for x in xdata:
    y=2*x
    ydata.append(y)
    
plt.plot(xdata,ydata,label='y=2x')
plt.xlim(0,35)
plt.xlim(0,70)
plt.xticks(list(range(0,35,2)))
plt.yticks(list(range(0,70,5)))

plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f28c4e851c5> in <module>
#       8 ydata=[]
#       9
# ---> 10 for x in xdata:
#      11     y=2*x
#      12     ydata.append(y)
#
# NameError: name 'xdata' is not defined
