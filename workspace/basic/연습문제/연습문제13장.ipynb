# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('high_school_2019.csv',skiprows = [0],
                names = ['지역','학교명','1학년 학급수','1학년 학생수','2학년 학급수','2학년 학생수', '3학년 학급수','3학년 학생수'])
                
df
# Out:
#                 지역                 학교명  1학년 학급수  1학년 학생수  2학년 학급수  2학년 학생수  \
# 0        서울특별시 강남구            국립국악고등학교        5      150        5      149
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교        8      239        8      228
# 2        서울특별시 금천구          국립전통예술고등학교        6      182        6      174
# 3        서울특별시 송파구              가락고등학교       11      282       11      262
# 4        서울특별시 강동구              강동고등학교        8      210        8      183
# ...            ...                 ...      ...      ...      ...      ...
# 2393   제주특별자치도 제주시              제주고등학교       11      279       11      279
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교        8      151        8      141
# 2395  제주특별자치도 서귀포시              성산고등학교        4       76        5       91
# 2396   제주특별자치도 제주시           제주외국어고등학교        4       99        4       95
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교        5      116        5       98
#
#       3학년 학급수  3학년 학생수
# 0           5      143
# ...

# %%
df2 = df.iloc[:,2:]

df2
# Out:
#       1학년 학급수  1학년 학생수  2학년 학급수  2학년 학생수  3학년 학급수  3학년 학생수
# 0           5      150        5      149        5      143
# 1           8      239        8      228        8      270
# 2           6      182        6      174        6      169
# 3          11      282       11      262       11      288
# 4           8      210        8      183        8      221
# ...       ...      ...      ...      ...      ...      ...
# 2393       11      279       11      279       11      305
# 2394        8      151        8      141        8      135
# 2395        4       76        5       91        5      103
# 2396        4       99        4       95        4       92
# 2397        5      116        5       98        5      126
#
# [2398 rows x 6 columns]

# %%
df2.isna()
# Out:
#       1학년 학급수  1학년 학생수  2학년 학급수  2학년 학생수  3학년 학급수  3학년 학생수
# 0       False    False    False    False    False    False
# 1       False    False    False    False    False    False
# 2       False    False    False    False    False    False
# 3       False    False    False    False    False    False
# 4       False    False    False    False    False    False
# ...       ...      ...      ...      ...      ...      ...
# 2393    False    False    False    False    False    False
# 2394    False    False    False    False    False    False
# 2395    False    False    False    False    False    False
# 2396    False    False    False    False    False    False
# 2397    False    False    False    False    False    False
#
# [2398 rows x 6 columns]

# %%
df2.fillna(0)
# Out:
#       1학년 학급수  1학년 학생수  2학년 학급수  2학년 학생수  3학년 학급수  3학년 학생수
# 0           5      150        5      149        5      143
# 1           8      239        8      228        8      270
# 2           6      182        6      174        6      169
# 3          11      282       11      262       11      288
# 4           8      210        8      183        8      221
# ...       ...      ...      ...      ...      ...      ...
# 2393       11      279       11      279       11      305
# 2394        8      151        8      141        8      135
# 2395        4       76        5       91        5      103
# 2396        4       99        4       95        4       92
# 2397        5      116        5       98        5      126
#
# [2398 rows x 6 columns]

# %%
df2['총 학생수'] = df2.sum(axis=1)

df2
# Out:
#       1학년 학급수  1학년 학생수  2학년 학급수  2학년 학생수  3학년 학급수  3학년 학생수  총 학생수
# 0           5      150        5      149        5      143    914
# 1           8      239        8      228        8      270   1522
# 2           6      182        6      174        6      169   1086
# 3          11      282       11      262       11      288   1730
# 4           8      210        8      183        8      221   1276
# ...       ...      ...      ...      ...      ...      ...    ...
# 2393       11      279       11      279       11      305   1792
# 2394        8      151        8      141        8      135    902
# 2395        4       76        5       91        5      103    568
# 2396        4       99        4       95        4       92    596
# 2397        5      116        5       98        5      126    710
#
# [2398 rows x 7 columns]

# %%
df.iloc[:,2:] = df.iloc[:,2:].astype(int)

# %%
df['총학생수'] = df[['1학년 학생수','2학년 학생수','3학년 학생수']].sum(axis=1)
df
# Out:
#                 지역                 학교명  1학년 학급수  1학년 학생수  2학년 학급수  2학년 학생수  \
# 0        서울특별시 강남구            국립국악고등학교        5      150        5      149
# 1        서울특별시 성북구     서울대학교사범대학부설고등학교        8      239        8      228
# 2        서울특별시 금천구          국립전통예술고등학교        6      182        6      174
# 3        서울특별시 송파구              가락고등학교       11      282       11      262
# 4        서울특별시 강동구              강동고등학교        8      210        8      183
# ...            ...                 ...      ...      ...      ...      ...
# 2393   제주특별자치도 제주시              제주고등학교       11      279       11      279
# 2394  제주특별자치도 서귀포시         서귀포산업과학고등학교        8      151        8      141
# 2395  제주특별자치도 서귀포시              성산고등학교        4       76        5       91
# 2396   제주특별자치도 제주시           제주외국어고등학교        4       99        4       95
# 2397   제주특별자치도 제주시  제주제일고등학교부설방송통신고등학교        5      116        5       98
#
#       3학년 학급수  3학년 학생수  총학생수
# 0           5      143   442
# ...

# %%
df2 = df[['1학년 학생수','2학년 학생수','3학년 학생수']].sum()
df2
# Out:
# 1학년 학생수    463400
# 2학년 학생수    444714
# 3학년 학생수    500698
# dtype: int64

# %%
df2.columns = ['1학년','2학년','3학년']

# %%
df2.plot.bar(rot=0)

plt.title('전국 고등학교 학년별 총 학생수')

plt.show()

# %% [markdown]
# # 14장

# %%
df = pd.read_csv('population_age_2020.csv')

df
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %%
df = df.sort_values(by=['100세 이상'],ascending=False)

df
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 14  경상북도   2658956   198214   233506   291097   303472   390995   464427
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# 13  전라남도   1861894   137868   172888   202760   193083   265366   317226
# 12  전라북도   1815112   135297   180675   212339   195971   274471   303074
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 15  경상남도   3358828   282751   331566   384750   418383   543911   585186
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# ...

# %%
df.iloc[:,[0,12,1]]
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 8    경기도     4010  13265377
# 1     부산     1807   3410925
# 14  경상북도      960   2658956
# 3     인천      908   2954955
# 11  충청남도      885   2120995
# 13  전라남도      822   1861894
# 12  전라북도      817   1815112
# 9    강원도      803   1539521
# 15  경상남도      739   3358828
# 2     대구      694   2432883
# 10  충청북도      541   1598599
# 4     광주      405   1456121
# 5     대전      339   1473125
# 16   제주도      266    670876
# 6     울산      160   1145710
# 7     세종       55    343788
